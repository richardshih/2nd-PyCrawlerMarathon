# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11855805585","type":"PushEvent","actor":{"id":7628308,"login":"droyed","display_login":"droyed","gravatar_id":"","url":"https://api.github.com/users/droyed","avatar_url":"https://avatars.githubusercontent.com/u/7628308?"},"repo":{"id":246223768,"name":"droyed/test_rtd_20200310_001","url":"https://api.github.com/repos/droyed/test_rtd_20200310_001"},"payload":{"push_id":4813324441,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"7f1d8b7820999f8a9c9e7666f6f520561e84bb6b","before":"f46d62dc384d485f99f111df48f6612b5c904ff5","commits":[{"sha":"7f1d8b7820999f8a9c9e7666f6f520561e84bb6b","author":{"email":"droygatech@gmail.com","name":"Divakar Roy"},"message":"test12","distinct":true,"url":"https://api.github.com/repos/droyed/test_rtd_20200310_001/commits/7f1d8b7820999f8a9c9e7666f6f520561e84bb6b"}]},"public":true,"created_at":"2020-03-25T05:37:35Z"},{"id":"11855805579","type":"IssueCommentEvent","actor":{"id":15736189,"login":"jlaari","display_login":"jlaari","gravatar_id":"","url":"https://api.github.com/users/jlaari","avatar_url":"https://avatars.githubusercontent.com/u/15736189?"},"repo":{"id":30675533,"name":"google/fonts","url":"https://api.github.com/repos/google/fonts"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/google/fonts/issues/1665","repository_url":"https://api.github.com/repos/google/fonts","labels_url":"https://api.github.com/repos/google/fonts/issues/1665/labels{/name}","comments_url":"https://api.github.com/repos/google/fonts/issues/1665/comments","events_url":"https://api.github.com/repos/google/fonts/issues/1665/events","html_url":"https://github.com/google/fonts/issues/1665","id":354289438,"node_id":"MDU6SXNzdWUzNTQyODk0Mzg=","number":1665,"title":"Add Space Grotesk","user":{"login":"mightybart","id":9280418,"node_id":"MDQ6VXNlcjkyODA0MTg=","avatar_url":"https://avatars0.githubusercontent.com/u/9280418?v=4","gravatar_id":"","url":"https://api.github.com/users/mightybart","html_url":"https://github.com/mightybart","followers_url":"https://api.github.com/users/mightybart/followers","following_url":"https://api.github.com/users/mightybart/following{/other_user}","gists_url":"https://api.github.com/users/mightybart/gists{/gist_id}","starred_url":"https://api.github.com/users/mightybart/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/mightybart/subscriptions","organizations_url":"https://api.github.com/users/mightybart/orgs","repos_url":"https://api.github.com/users/mightybart/repos","events_url":"https://api.github.com/users/mightybart/events{/privacy}","received_events_url":"https://api.github.com/users/mightybart/received_events","type":"User","site_admin":false},"labels":[{"id":422735541,"node_id":"MDU6TGFiZWw0MjI3MzU1NDE=","url":"https://api.github.com/repos/google/fonts/labels/Priority%202%20-%20Important%20but%20not%20Urgent","name":"Priority 2 - Important but not Urgent","color":"c5def5","default":false,"description":null}],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":{"url":"https://api.github.com/repos/google/fonts/milestones/2","html_url":"https://github.com/google/fonts/milestone/2","labels_url":"https://api.github.com/repos/google/fonts/milestones/2/labels","id":1873155,"node_id":"MDk6TWlsZXN0b25lMTg3MzE1NQ==","number":2,"title":"Add New Families","description":"","creator":{"login":"davelab6","id":261579,"node_id":"MDQ6VXNlcjI2MTU3OQ==","avatar_url":"https://avatars0.githubusercontent.com/u/261579?v=4","gravatar_id":"","url":"https://api.github.com/users/davelab6","html_url":"https://github.com/davelab6","followers_url":"https://api.github.com/users/davelab6/followers","following_url":"https://api.github.com/users/davelab6/following{/other_user}","gists_url":"https://api.github.com/users/davelab6/gists{/gist_id}","starred_url":"https://api.github.com/users/davelab6/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/davelab6/subscriptions","organizations_url":"https://api.github.c ...

# %%
import json

json.loads(r.text)
# Out:
# [{'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/7628308?',
#    'display_login': 'droyed',
#    'gravatar_id': '',
#    'id': 7628308,
#    'login': 'droyed',
#    'url': 'https://api.github.com/users/droyed'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805585',
#   'payload': {'before': 'f46d62dc384d485f99f111df48f6612b5c904ff5',
#    'commits': [{'author': {'email': 'droygatech@gmail.com',
#       'name': 'Divakar Roy'},
#      'distinct': True,
#      'message': 'test12',
#      'sha': '7f1d8b7820999f8a9c9e7666f6f520561e84bb6b',
#      'url': 'https://api.github.com/repos/droyed/test_rtd_20200310_001/commits/7f1d8b7820999f8a9c9e7666f6f520561e84bb6b'}],
#    'distinct_size': 1,
#    'head': '7f1d8b7820999f8a9c9e7666f6f520561e84bb6b',
#    'push_id': 4813324441,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 246223768,
#    'name': 'droyed/test_rtd_20200310_001',
#    'url': 'https://api.github.com/repos/droyed/test_rtd_20200310_001'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/15736189?',
#    'display_login': 'jlaari',
#    'gravatar_id': '',
#    'id': 15736189,
#    'login': 'jlaari',
#    'url': 'https://api.github.com/users/jlaari'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805579',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/1342004?',
#    'gravatar_id': '',
#    'id': 1342004,
#    'login': 'google',
#    'url': 'https://api.github.com/orgs/google'},
#   'payload': {'action': 'created',
#    'comment': {'author_association': 'NONE',
#     'body': 'Waiting this.',
#     'created_at': '2020-03-25T05:37:35Z',
#     'html_url': 'https://github.com/google/fonts/issues/1665#issuecomment-603650652',
#     'id': 603650652,
#     'issue_url': 'https://api.github.com/repos/google/fonts/issues/1665',
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDYwMzY1MDY1Mg==',
#     'updated_at': '2020-03-25T05:37:35Z',
#     'url': 'https://api.github.com/repos/google/fonts/issues/comments/603650652',
#     'user': {'avatar_url': 'https://avatars2.githubusercontent.com/u/15736189?v=4',
#      'events_url': 'https://api.github.com/users/jlaari/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/jlaari/followers',
#      'following_url': 'https://api.github.com/users/jlaari/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jlaari/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/jlaari',
#      'id': 15736189,
#      'login': 'jlaari',
#      'node_id': 'MDQ6VXNlcjE1NzM2MTg5',
#      'organizations_url': 'https://api.github.com/users/jlaari/orgs',
#      'received_events_url': 'https://api.github.com/users/jlaari/received_events',
#      'repos_url': 'https://api.github.com/users/jlaari/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/jlaari/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jlaari/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/jlaari'}},
#    'issue': {'assignee': None,
#     'assignees': [],
#     'author_association': 'NONE',
#     'body': 'GitHub repository: https://github.com/floriankarsten/space-grotesk\r\n\r\nSpace Grotesk is a proportional version of Space Mono (Colophon Foundry, 2016). Available in five weights (Light, Regular, Medium, SemiBold, Bold). Designed by [Florian Karsten](https://floriankarsten.com).\r\n\r\n![Space Grotesk by Florian Karsten](https://fonts.floriankarsten.com/files/space-grotesk-about.png)\r\n\r\nSpace Grotesk supports Latin Extended-A character set and several OpenType features. For complete specs see typeface [specimen](https://fonts.floriankarsten.com/space-grotesk/space_grotesk_specimen.pdf) (PDF, 2.3 MB).\r\n\r\nType tester available at [fonts.floriankarsten.com](https://fonts.floriankarsten.com/space-grotesk).\r\n\r\n![Space Grotesk Preview](https://fonts.floriankarsten.com/files/space-grotesk-styles.png)',
#     'closed_at': None,
#     'comments': 4,
#     'comments_url': 'https://api.github.com/repos/google/fonts/issues/1665/comments',
#     'created_at': '2018-08-27T11:57:26Z',
#     'events_url': 'https://api.github.com/repos/google/fonts/issues/1665/events',
#     'html_url': 'https://github.com/google/fonts/issues/1665',
#     'id': 354289438,
#     'labels': [{'color': 'c5def5',
#       'default': False,
#       'description': None,
#       'id': 422735541,
#       'name': 'Priority 2 - Important but not Urgent',
#       'node_id': 'MDU6TGFiZWw0MjI3MzU1NDE=',
#       'url': 'https://api.github.com/repos/google/fonts/labels/Priority%202%20-%20Important%20but%20not%20Urgent'}],
#     'labels_url': 'https://api.github.com/repos/google/fonts/issues/1665/labels{/name}',
#     'locked': False,
#     'milestone': {'closed_at': None,
#      'closed_issues': 51,
#      'created_at': '2016-07-08T22:18:14Z',
#      'creator': {'avatar_url': 'https://avatars0.githubusercontent.com/u/261579?v=4',
#       'events_url': 'https://api.github.com/users/davelab6/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/davelab6/followers',
#       'following_url': 'https://api.github.com/users/davelab6/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/davelab6/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/davelab6',
#       'id': 261579,
#       'login': 'davelab6',
#       'node_id': 'MDQ6VXNlcjI2MTU3OQ==',
#       'organizations_url': 'https://api.github.com/users/davelab6/orgs',
#       'received_events_url': 'https://api.github.com/users/davelab6/received_events',
#       'repos_url': 'https://api.github.com/users/davelab6/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/davelab6/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/davelab6/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/davelab6'},
#      'description': '',
#      'due_on': None,
#      'html_url': 'https://github.com/google/fonts/milestone/2',
#      'id': 1873155,
#      'labels_url': 'https://api.github.com/repos/google/fonts/milestones/2/labels',
#      'node_id': 'MDk6TWlsZXN0b25lMTg3MzE1NQ==',
#      'number': 2,
#      'open_issues': 146,
#      'state': 'open',
#      'title': 'Add New Families',
#      'updated_at': '2020-03-06T09:41:42Z',
#      'url': 'https://api.github.com/repos/google/fonts/milestones/2'},
#     'node_id': 'MDU6SXNzdWUzNTQyODk0Mzg=',
#     'number': 1665,
#     'repository_url': 'https://api.github.com/repos/google/fonts',
#     'state': 'open',
#     'title': 'Add Space Grotesk',
#     'updated_at': '2020-03-25T05:37:35Z',
#     'url': 'https://api.github.com/repos/google/fonts/issues/1665',
#     'user': {'avatar_url': 'https://avatars0.githubusercontent.com/u/9280418?v=4',
#      'events_url': 'https://api.github.com/users/mightybart/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/mightybart/followers',
#      'following_url': 'https://api.github.com/users/mightybart/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mightybart/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/mightybart',
#      'id': 9280418,
#      'login': 'mightybart',
#      'node_id': 'MDQ6VXNlcjkyODA0MTg=',
#      'organizations_url': 'https://api.github.com/users/mightybart/orgs',
#      'received_events_url': 'https://api.github.com/users/mightybart/received_events',
#      'repos_url': 'https://api.github.com/users/mightybart/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/mightybart/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mightybart/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/mightybart'}}},
#   'public': True,
#   'repo': {'id': 30675533,
#    'name': 'google/fonts',
#    'url': 'https://api.github.com/repos/google/fonts'},
#   'type': 'IssueCommentEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/10006640?',
#    'display_login': 'basstal',
#    'gravatar_id': '',
#    'id': 10006640,
#    'login': 'basstal',
#    'url': 'https://api.github.com/users/basstal'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805577',
#   'payload': {'before': '6040e149050ae26089f6730a6f35fe5fb624fd8d',
#    'commits': [{'author': {'email': '330475004@qq.com', 'name': 'basstal'},
#      'distinct': True,
#      'message': 'c28 update',
#      'sha': '7e051bbb424a7bcd37bc606c24e0b675b9f88b96',
#      'url': 'https://api.github.com/repos/basstal/ProgrammingInLua/commits/7e051bbb424a7bcd37bc606c24e0b675b9f88b96'}],
#    'distinct_size': 1,
#    'head': '7e051bbb424a7bcd37bc606c24e0b675b9f88b96',
#    'push_id': 4813324437,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 229514541,
#    'name': 'basstal/ProgrammingInLua',
#    'url': 'https://api.github.com/repos/basstal/ProgrammingInLua'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/54923505?',
#    'display_login': 'Kai-Su0326',
#    'gravatar_id': '',
#    'id': 54923505,
#    'login': 'Kai-Su0326',
#    'url': 'https://api.github.com/users/Kai-Su0326'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805573',
#   'payload': {'before': 'bfb39fde2f8dbb76dc4d923e582e2992bfca458f',
#    'commits': [{'author': {'email': '54923505+Kai-Su0326@users.noreply.github.com',
#       'name': 'Jingkai Su'},
#      'distinct': True,
#      'message': 'Delete ttt.java',
#      'sha': 'df985d26b28aa66471e0eb236cd2f67c304ca59c',
#      'url': 'https://api.github.com/repos/Kai-Su0326/Software-Engineering-Projects/commits/df985d26b28aa66471e0eb236cd2f67c304ca59c'}],
#    'distinct_size': 1,
#    'head': 'df985d26b28aa66471e0eb236cd2f67c304ca59c',
#    'push_id': 4813324435,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 249886832,
#    'name': 'Kai-Su0326/Software-Engineering-Projects',
#    'url': 'https://api.github.com/repos/Kai-Su0326/Software-Engineering-Projects'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805566',
#   'payload': {'action': 'closed',
#    'number': 47,
#    'pull_request': {'_links': {'comments': {'href': 'https://api.github.com/repos/ghostslayer989/gitfolio/issues/47/comments'},
#      'commits': {'href': 'https://api.github.com/repos/ghostslayer989/gitfolio/pulls/47/commits'},
#      'html': {'href': 'https://github.com/ghostslayer989/gitfolio/pull/47'},
#      'issue': {'href': 'https://api.github.com/repos/ghostslayer989/gitfolio/issues/47'},
#      'review_comment': {'href': 'https://api.github.com/repos/ghostslayer989/gitfolio/pulls/comments{/number}'},
#      'review_comments': {'href': 'https://api.github.com/repos/ghostslayer989/gitfolio/pulls/47/comments'},
#      'self': {'href': 'https://api.github.com/repos/ghostslayer989/gitfolio/pulls/47'},
#      'statuses': {'href': 'https://api.github.com/repos/ghostslayer989/gitfolio/statuses/59574c68cb23e22ee8a628786e8ac6bb4d17332e'}},
#     'additions': 994,
#     'assignee': None,
#     'assignees': [],
#     'author_association': 'NONE',
#     'base': {'label': 'ghostslayer989:master',
#      'ref': 'master',
#      'repo': {'archive_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/branches{/branch}',
#       'clone_url': 'https://github.com/ghostslayer989/gitfolio.git',
#       'collaborators_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/contributors',
#       'created_at': '2019-05-20T16:34:23Z',
#       'default_branch': 'master',
#       'deployments_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/deployments',
#       'description': ':octocat: personal website + blog  for every github user',
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/downloads',
#       'events_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/events',
#       'fork': True,
#       'forks': 0,
#       'forks_count': 0,
#       'forks_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/forks',
#       'full_name': 'ghostslayer989/gitfolio',
#       'git_commits_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/git/tags{/sha}',
#       'git_url': 'git://github.com/ghostslayer989/gitfolio.git',
#       'has_downloads': True,
#       'has_issues': False,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': 'https://imfunniee.github.io/gitfolio/',
#       'hooks_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/hooks',
#       'html_url': 'https://github.com/ghostslayer989/gitfolio',
#       'id': 187677718,
#       'issue_comment_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/labels{/name}',
#       'language': 'JavaScript',
#       'languages_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/languages',
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'node_id': 'MDc6TGljZW5zZTk=',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0'},
#       'merges_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/merges',
#       'milestones_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/milestones{/number}',
#       'mirror_url': None,
#       'name': 'gitfolio',
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODc2Nzc3MTg=',
#       'notifications_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/notifications{?since,all,participating}',
#       'open_issues': 8,
#       'open_issues_count': 8,
#       'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/45863583?v=4',
#        'events_url': 'https://api.github.com/users/ghostslayer989/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/ghostslayer989/followers',
#        'following_url': 'https://api.github.com/users/ghostslayer989/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ghostslayer989/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/ghostslayer989',
#        'id': 45863583,
#        'login': 'ghostslayer989',
#        'node_id': 'MDQ6VXNlcjQ1ODYzNTgz',
#        'organizations_url': 'https://api.github.com/users/ghostslayer989/orgs',
#        'received_events_url': 'https://api.github.com/users/ghostslayer989/received_events',
#        'repos_url': 'https://api.github.com/users/ghostslayer989/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/ghostslayer989/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ghostslayer989/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/ghostslayer989'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/pulls{/number}',
#       'pushed_at': '2020-03-25T05:37:32Z',
#       'releases_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/releases{/id}',
#       'size': 171,
#       'ssh_url': 'git@github.com:ghostslayer989/gitfolio.git',
#       'stargazers_count': 0,
#       'stargazers_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/stargazers',
#       'statuses_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/subscription',
#       'svn_url': 'https://github.com/ghostslayer989/gitfolio',
#       'tags_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/tags',
#       'teams_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/teams',
#       'trees_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/git/trees{/sha}',
#       'updated_at': '2019-05-20T16:34:26Z',
#       'url': 'https://api.github.com/repos/ghostslayer989/gitfolio',
#       'watchers': 0,
#       'watchers_count': 0},
#      'sha': '3a1731c77661b4268675404ccb77212fef2b2473',
#      'user': {'avatar_url': 'https://avatars2.githubusercontent.com/u/45863583?v=4',
#       'events_url': 'https://api.github.com/users/ghostslayer989/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/ghostslayer989/followers',
#       'following_url': 'https://api.github.com/users/ghostslayer989/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ghostslayer989/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/ghostslayer989',
#       'id': 45863583,
#       'login': 'ghostslayer989',
#       'node_id': 'MDQ6VXNlcjQ1ODYzNTgz',
#       'organizations_url': 'https://api.github.com/users/ghostslayer989/orgs',
#       'received_events_url': 'https://api.github.com/users/ghostslayer989/received_events',
#       'repos_url': 'https://api.github.com/users/ghostslayer989/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/ghostslayer989/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ghostslayer989/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/ghostslayer989'}},
#     'body': 'Bumps [got](https://github.com/sindresorhus/got) from 9.6.0 to 10.6.0.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/sindresorhus/got/releases">got\'s releases</a>.</em></p>\n<blockquote>\n<h2>v10.6.0</h2>\n<ul>\n<li>Add <a href="https://github.com/sindresorhus/got#allowgetbody"><code>allowGetBody</code></a> option to allow GET requests with payload (<a href="https://github-redirect.dependabot.com/sindresorhus/got/issues/1081">#1081</a>)  526b4bb</li>\n</ul>\n<p><a href="https://github.com/sindresorhus/got/compare/v10.5.7...v10.6.0">https://github.com/sindresorhus/got/compare/v10.5.7...v10.6.0</a></p>\n<h2>v10.5.7</h2>\n<ul>\n<li>Fix Init hooks not being called if extended acefaa4c2a0cb3c33b3f952be29ac0a9cb316e87</li>\n</ul>\n<h2>v10.5.6</h2>\n<ul>\n<li>Fix Init hook logic 64aeb40d824008db48c956a3e03807383be62090</li>\n<li>Update dependencies 32e609f3bb4c4021cf8b98886efa9bc23e99cc9d</li>\n</ul>\n<h2>v10.5.5</h2>\n<ul>\n<li>Fix merging pagination options 1f363b976cd23626462314c7cd5670cddd951c73</li>\n</ul>\n<h2>v10.5.4</h2>\n<ul>\n<li>Fix <code>_pagination</code> not falling back to defaults ff1dba1e0c6f190da55d2799ebaa7a167f49ae9a</li>\n</ul>\n<h2>v10.5.3</h2>\n<ul>\n<li>Fix unhandled errors if throwing in an async handler 518d95aba5fde83d6708ee1289561fa445870436</li>\n</ul>\n<h2>v10.5.2</h2>\n<ul>\n<li>Forgot to include required <code>p-event</code> dependency  8373112</li>\n</ul>\n<p><a href="https://github.com/sindresorhus/got/compare/v10.5.1...v10.5.2">https://github.com/sindresorhus/got/compare/v10.5.1...v10.5.2</a></p>\n<h2>v10.5.1</h2>\n<ul>\n<li>Wait until body file descriptor is open (<a href="https://github-redirect.dependabot.com/sindresorhus/got/issues/1054">#1054</a>)  453a3a3</li>\n</ul>\n<p><a href="https://github.com/sindresorhus/got/compare/v10.5.0...v10.5.1">https://github.com/sindresorhus/got/compare/v10.5.0...v10.5.1</a></p>\n<h2>v10.5.0</h2>\n<ul>\n<li>Add experimental <a href="https://github.com/sindresorhus/got#pagination">pagination</a> feature (<a href="https://github-redirect.dependabot.com/sindresorhus/got/issues/833">#833</a>)  761c7c6\nWe\'re looking for <a href="https://github-redirect.dependabot.com/sindresorhus/got/issues/1052">feedback</a> on how it works.</li>\n</ul>\n<p><a href="https://github.com/sindresorhus/got/compare/v10.4.0...v10.5.0">https://github.com/sindresorhus/got/compare/v10.4.0...v10.5.0</a></p>\n<h2>v10.4.0</h2>\n<ul>\n<li>Update <code>@szmarczak/cacheable-lookup</code> dependency  d527dae</li>\n<li>Include invalid JSON body in <code>ParseError</code>s (<a href="https://github-redirect.dependabot.com/sindresorhus/got/issues/1044">#1044</a>)  2813b73</li>\n<li>Fix <code>got.stream(...)</code> not throwing <code>ReadError</code>s  1f6ca6b</li>\n</ul>\n<p><a href="https://github.com/sindresorhus/got/compare/v10.3.0...v10.4.0">https://github.com/sindresorhus/got/compare/v10.3.0...v10.4.0</a></p>\n<h2>v10.3.0</h2>\n<ul>\n<li>Allow request body to be sent with a DELETE request (<a href="https://github-redirect.dependabot.com/sindresorhus/got/issues/1037">#1037</a>)  17d629a</li>\n<li>Reject normalization errors with CancelableRequest (<a href="https://github-redirect.dependabot.com/sindresorhus/got/issues/1035">#1035</a>)  fddecab</li>\n<li>Export <code>GotRequestMethod</code> TypeScript type (<a href="https://github-redirect.dependabot.com/sindresorhus/got/issues/1017">#1017</a>)  f02694e</li>\n<li>Export <code>ReadError</code> TypeScript type (<a href="https://github-redirect.dependabot.com/sindresorhus/got/issues/1027">#1027</a>)  d222164</li>\n</ul>\n</tr></table> ... (truncated)\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/sindresorhus/got/commit/33a696694ebb2bd1c995f4800344fdf9b7fa1e86"><code>33a6966</code></a> 10.6.0</li>\n<li><a href="https://github.com/sindresorhus/got/commit/526b4bb03eed5196a3c6375beeb7699e8f512d4f"><code>526b4bb</code></a> Add option <co ...
#     'changed_files': 2,
#     'closed_at': '2020-03-25T05:37:34Z',
#     'comments': 1,
#     'comments_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/issues/47/comments',
#     'commits': 1,
#     'commits_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/pulls/47/commits',
#     'created_at': '2020-02-21T05:31:47Z',
#     'deletions': 925,
#     'diff_url': 'https://github.com/ghostslayer989/gitfolio/pull/47.diff',
#     'draft': False,
#     'head': {'label': 'ghostslayer989:dependabot/npm_and_yarn/got-10.6.0',
#      'ref': 'dependabot/npm_and_yarn/got-10.6.0',
#      'repo': {'archive_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/branches{/branch}',
#       'clone_url': 'https://github.com/ghostslayer989/gitfolio.git',
#       'collaborators_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/contributors',
#       'created_at': '2019-05-20T16:34:23Z',
#       'default_branch': 'master',
#       'deployments_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/deployments',
#       'description': ':octocat: personal website + blog  for every github user',
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/downloads',
#       'events_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/events',
#       'fork': True,
#       'forks': 0,
#       'forks_count': 0,
#       'forks_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/forks',
#       'full_name': 'ghostslayer989/gitfolio',
#       'git_commits_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/git/tags{/sha}',
#       'git_url': 'git://github.com/ghostslayer989/gitfolio.git',
#       'has_downloads': True,
#       'has_issues': False,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': 'https://imfunniee.github.io/gitfolio/',
#       'hooks_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/hooks',
#       'html_url': 'https://github.com/ghostslayer989/gitfolio',
#       'id': 187677718,
#       'issue_comment_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/labels{/name}',
#       'language': 'JavaScript',
#       'languages_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/languages',
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'node_id': 'MDc6TGljZW5zZTk=',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0'},
#       'merges_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/merges',
#       'milestones_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/milestones{/number}',
#       'mirror_url': None,
#       'name': 'gitfolio',
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODc2Nzc3MTg=',
#       'notifications_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/notifications{?since,all,participating}',
#       'open_issues': 8,
#       'open_issues_count': 8,
#       'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/45863583?v=4',
#        'events_url': 'https://api.github.com/users/ghostslayer989/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/ghostslayer989/followers',
#        'following_url': 'https://api.github.com/users/ghostslayer989/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ghostslayer989/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/ghostslayer989',
#        'id': 45863583,
#        'login': 'ghostslayer989',
#        'node_id': 'MDQ6VXNlcjQ1ODYzNTgz',
#        'organizations_url': 'https://api.github.com/users/ghostslayer989/orgs',
#        'received_events_url': 'https://api.github.com/users/ghostslayer989/received_events',
#        'repos_url': 'https://api.github.com/users/ghostslayer989/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/ghostslayer989/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ghostslayer989/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/ghostslayer989'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/pulls{/number}',
#       'pushed_at': '2020-03-25T05:37:32Z',
#       'releases_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/releases{/id}',
#       'size': 171,
#       'ssh_url': 'git@github.com:ghostslayer989/gitfolio.git',
#       'stargazers_count': 0,
#       'stargazers_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/stargazers',
#       'statuses_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/subscription',
#       'svn_url': 'https://github.com/ghostslayer989/gitfolio',
#       'tags_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/tags',
#       'teams_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/teams',
#       'trees_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/git/trees{/sha}',
#       'updated_at': '2019-05-20T16:34:26Z',
#       'url': 'https://api.github.com/repos/ghostslayer989/gitfolio',
#       'watchers': 0,
#       'watchers_count': 0},
#      'sha': '59574c68cb23e22ee8a628786e8ac6bb4d17332e',
#      'user': {'avatar_url': 'https://avatars2.githubusercontent.com/u/45863583?v=4',
#       'events_url': 'https://api.github.com/users/ghostslayer989/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/ghostslayer989/followers',
#       'following_url': 'https://api.github.com/users/ghostslayer989/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ghostslayer989/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/ghostslayer989',
#       'id': 45863583,
#       'login': 'ghostslayer989',
#       'node_id': 'MDQ6VXNlcjQ1ODYzNTgz',
#       'organizations_url': 'https://api.github.com/users/ghostslayer989/orgs',
#       'received_events_url': 'https://api.github.com/users/ghostslayer989/received_events',
#       'repos_url': 'https://api.github.com/users/ghostslayer989/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/ghostslayer989/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ghostslayer989/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/ghostslayer989'}},
#     'html_url': 'https://github.com/ghostslayer989/gitfolio/pull/47',
#     'id': 378111519,
#     'issue_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/issues/47',
#     'labels': [{'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file',
#       'id': 1369569053,
#       'name': 'dependencies',
#       'node_id': 'MDU6TGFiZWwxMzY5NTY5MDUz',
#       'url': 'https://api.github.com/repos/ghostslayer989/gitfolio/labels/dependencies'}],
#     'locked': False,
#     'maintainer_can_modify': False,
#     'merge_commit_sha': 'c80beb787d5246a521d540c777a42f4874f7d14b',
#     'mergeable': True,
#     'mergeable_state': 'clean',
#     'merged': False,
#     'merged_at': None,
#     'merged_by': None,
#     'milestone': None,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzc4MTExNTE5',
#     'number': 47,
#     'patch_url': 'https://github.com/ghostslayer989/gitfolio/pull/47.patch',
#     'rebaseable': True,
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'review_comment_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/pulls/comments{/number}',
#     'review_comments': 0,
#     'review_comments_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/pulls/47/comments',
#     'state': 'closed',
#     'statuses_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/statuses/59574c68cb23e22ee8a628786e8ac6bb4d17332e',
#     'title': 'Bump got from 9.6.0 to 10.6.0',
#     'updated_at': '2020-03-25T05:37:34Z',
#     'url': 'https://api.github.com/repos/ghostslayer989/gitfolio/pulls/47',
#     'user': {'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'id': 27856297,
#      'login': 'dependabot-preview[bot]',
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'type': 'Bot',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D'}}},
#   'public': True,
#   'repo': {'id': 187677718,
#    'name': 'ghostslayer989/gitfolio',
#    'url': 'https://api.github.com/repos/ghostslayer989/gitfolio'},
#   'type': 'PullRequestEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/11490396?',
#    'display_login': 'viveknalubandu',
#    'gravatar_id': '',
#    'id': 11490396,
#    'login': 'viveknalubandu',
#    'url': 'https://api.github.com/users/viveknalubandu'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805560',
#   'payload': {'before': 'a88438e709797ef20479c9779e1d0a24e79b0bca',
#    'commits': [{'author': {'email': 'vivek091@gmail.com',
#       'name': 'viveknalubandu'},
#      'distinct': True,
#      'message': 'Set hot fix 10.0-HOTFIX1\n\nSet hot fix 10.0-HOTFIX1',
#      'sha': '3fd7e382e4d16c8866cce4ff157b4d01206f73f9',
#      'url': 'https://api.github.com/repos/viveknalubandu/samplejava/commits/3fd7e382e4d16c8866cce4ff157b4d01206f73f9'}],
#    'distinct_size': 1,
#    'head': '3fd7e382e4d16c8866cce4ff157b4d01206f73f9',
#    'push_id': 4813324434,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 247627861,
#    'name': 'viveknalubandu/samplejava',
#    'url': 'https://api.github.com/repos/viveknalubandu/samplejava'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/2841489?',
#    'display_login': 'jordan-rosenfeld',
#    'gravatar_id': '',
#    'id': 2841489,
#    'login': 'jordan-rosenfeld',
#    'url': 'https://api.github.com/users/jordan-rosenfeld'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805568',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/62514696?',
#    'gravatar_id': '',
#    'id': 62514696,
#    'login': 'openventilatorregistry',
#    'url': 'https://api.github.com/orgs/openventilatorregistry'},
#   'payload': {'description': None,
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': 'master',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 249895859,
#    'name': 'openventilatorregistry/OVR-API',
#    'url': 'https://api.github.com/repos/openventilatorregistry/OVR-API'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/518969?',
#    'display_login': 'qxhy123',
#    'gravatar_id': '',
#    'id': 518969,
#    'login': 'qxhy123',
#    'url': 'https://api.github.com/users/qxhy123'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805557',
#   'payload': {'before': '9d2871dfd7cdb3ec86afdd11f14c5ec51846f7f1',
#    'commits': [{'author': {'email': 'qxhy123@gmail.com',
#       'name': 'Michael Yang'},
#      'distinct': True,
#      'message': 'UCP: Support code highlight and auto format SQL',
#      'sha': 'debb63fe4af81c7956ffcea65eee496513634097',
#      'url': 'https://api.github.com/repos/qxhy123/tidb-dashboard/commits/debb63fe4af81c7956ffcea65eee496513634097'}],
#    'distinct_size': 1,
#    'head': 'debb63fe4af81c7956ffcea65eee496513634097',
#    'push_id': 4813324432,
#    'ref': 'refs/heads/sql-highlight',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 246763976,
#    'name': 'qxhy123/tidb-dashboard',
#    'url': 'https://api.github.com/repos/qxhy123/tidb-dashboard'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/60076774?',
#    'display_login': 'Williams7105',
#    'gravatar_id': '',
#    'id': 60076774,
#    'login': 'Williams7105',
#    'url': 'https://api.github.com/users/Williams7105'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805551',
#   'payload': {'before': '95b9edbb917ce1d446a428e2bb95c61669d47ca7',
#    'commits': [{'author': {'email': '60076774+Williams7105@users.noreply.github.com',
#       'name': 'Williams Martinez'},
#      'distinct': True,
#      'message': 'Update nav.html',
#      'sha': 'ff63fafcd154af59e43a8dd9fe96c223cd74af27',
#      'url': 'https://api.github.com/repos/Williams7105/williams7105/commits/ff63fafcd154af59e43a8dd9fe96c223cd74af27'}],
#    'distinct_size': 1,
#    'head': 'ff63fafcd154af59e43a8dd9fe96c223cd74af27',
#    'push_id': 4813324422,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 249892666,
#    'name': 'Williams7105/williams7105',
#    'url': 'https://api.github.com/repos/Williams7105/williams7105'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/9038737?',
#    'display_login': 'gcquirozguzman',
#    'gravatar_id': '',
#    'id': 9038737,
#    'login': 'gcquirozguzman',
#    'url': 'https://api.github.com/users/gcquirozguzman'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805530',
#   'payload': {'before': '0a5ed678c25410b9307fa9351922229515196ea4',
#    'commits': [{'author': {'email': 'gcquirozguzman@users.noreply.github.com',
#       'name': 'Gian Carlo Quiroz Guzman'},
#      'distinct': True,
#      'message': 'Update README.md',
#      'sha': '47cb3714fdc6a510ec0a0cc315f71d54e4ad9979',
#      'url': 'https://api.github.com/repos/gcquirozguzman/java-tcs-202001/commits/47cb3714fdc6a510ec0a0cc315f71d54e4ad9979'}],
#    'distinct_size': 1,
#    'head': '47cb3714fdc6a510ec0a0cc315f71d54e4ad9979',
#    'push_id': 4813324409,
#    'ref': 'refs/heads/STI0100001',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 232239771,
#    'name': 'gcquirozguzman/java-tcs-202001',
#    'url': 'https://api.github.com/repos/gcquirozguzman/java-tcs-202001'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/5033229?',
#    'display_login': 'jaeddy',
#    'gravatar_id': '',
#    'id': 5033229,
#    'login': 'jaeddy',
#    'url': 'https://api.github.com/users/jaeddy'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805529',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/6921777?',
#    'gravatar_id': '',
#    'id': 6921777,
#    'login': 'ga4gh',
#    'url': 'https://api.github.com/orgs/ga4gh'},
#   'payload': {'before': '456ed0bed35218b88f6300aed0a07117a022bbf4',
#    'commits': [{'author': {'email': 'james.a.eddy@gmail.com',
#       'name': 'James Eddy'},
#      'distinct': False,
#      'message': 'replace swagger-repo with openapi-cli; remove alias scripts',
#      'sha': 'c6e736494cf1417ba01ef961a16526f518b325c9',
#      'url': 'https://api.github.com/repos/ga4gh/gh-openapi-docs/commits/c6e736494cf1417ba01ef961a16526f518b325c9'},
#     {'author': {'email': 'james.a.eddy@gmail.com', 'name': 'James Eddy'},
#      'distinct': False,
#      'message': "remove 'run npm' from exec calls and fix cli syntax",
#      'sha': '7c1e26781e91ba2d407c0d2fd656a75610ecac4e',
#      'url': 'https://api.github.com/repos/ga4gh/gh-openapi-docs/commits/7c1e26781e91ba2d407c0d2fd656a75610ecac4e'},
#     {'author': {'email': 'james.a.eddy@gmail.com', 'name': 'James Eddy'},
#      'distinct': True,
#      'message': 'Merge pull request #13 from ga4gh/fix-cli-dependencies\n\nFix CLI dependencies',
#      'sha': '22156603c351b860a127bb43e3c55cc6ef957520',
#      'url': 'https://api.github.com/repos/ga4gh/gh-openapi-docs/commits/22156603c351b860a127bb43e3c55cc6ef957520'}],
#    'distinct_size': 1,
#    'head': '22156603c351b860a127bb43e3c55cc6ef957520',
#    'push_id': 4813324397,
#    'ref': 'refs/heads/master',
#    'size': 3},
#   'public': True,
#   'repo': {'id': 184825484,
#    'name': 'ga4gh/gh-openapi-docs',
#    'url': 'https://api.github.com/repos/ga4gh/gh-openapi-docs'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/8434197?',
#    'display_login': 'Pandi0604',
#    'gravatar_id': '',
#    'id': 8434197,
#    'login': 'Pandi0604',
#    'url': 'https://api.github.com/users/Pandi0604'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805526',
#   'payload': {'before': 'dd7fc0065a242c9187058135fe643971c29d9942',
#    'commits': [{'author': {'email': 'pandi0604@163.com', 'name': 'Pandi0604'},
#      'distinct': False,
#      'message': 'Update README.md',
#      'sha': '189ecbdd3cf643c75a393dee00ddcdc046f1bc1e',
#      'url': 'https://api.github.com/repos/Pandi0604/Hello_World/commits/189ecbdd3cf643c75a393dee00ddcdc046f1bc1e'},
#     {'author': {'email': 'pandi0604@163.com', 'name': 'Pandi0604'},
#      'distinct': True,
#      'message': 'Merge pull request #1 from Pandi0604/readme-edits\n\nUpdate README.md',
#      'sha': '1bdd8c4f2da07d30333dc1c18ec6344f36ff88f0',
#      'url': 'https://api.github.com/repos/Pandi0604/Hello_World/commits/1bdd8c4f2da07d30333dc1c18ec6344f36ff88f0'}],
#    'distinct_size': 1,
#    'head': '1bdd8c4f2da07d30333dc1c18ec6344f36ff88f0',
#    'push_id': 4813324405,
#    'ref': 'refs/heads/master',
#    'size': 2},
#   'public': True,
#   'repo': {'id': 249869829,
#    'name': 'Pandi0604/Hello_World',
#    'url': 'https://api.github.com/repos/Pandi0604/Hello_World'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/59524605?',
#    'display_login': 'kamitoshi',
#    'gravatar_id': '',
#    'id': 59524605,
#    'login': 'kamitoshi',
#    'url': 'https://api.github.com/users/kamitoshi'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805519',
#   'payload': {'before': '85cfc3fa47ff9d42bec2abb9586fda4cedf56aee',
#    'commits': [{'author': {'email': 'kroo.aq.74@gmail.com',
#       'name': 'kamitoshi'},
#      'distinct': False,
#      'message': 'model case',
#      'sha': 'c8820cffc368755d8da00878951eddf4301e04c1',
#      'url': 'https://api.github.com/repos/kamitoshi/sample/commits/c8820cffc368755d8da00878951eddf4301e04c1'},
#     {'author': {'email': 'kroo.aq.74@gmail.com', 'name': 'kamitoshi'},
#      'distinct': False,
#      'message': 'Add test users',
#      'sha': 'fa32ef841eee8ba3e311c434ecee54a3b1f61b1b',
#      'url': 'https://api.github.com/repos/kamitoshi/sample/commits/fa32ef841eee8ba3e311c434ecee54a3b1f61b1b'},
#     {'author': {'email': 'kroo.aq.74@gmail.com', 'name': 'kamitoshi'},
#      'distinct': True,
#      'message': 'Make a basic User model(including secure passwords)',
#      'sha': '373c5e8e2b9a0a87898e3b8c2ae6736682d11ad7',
#      'url': 'https://api.github.com/repos/kamitoshi/sample/commits/373c5e8e2b9a0a87898e3b8c2ae6736682d11ad7'}],
#    'distinct_size': 1,
#    'head': '373c5e8e2b9a0a87898e3b8c2ae6736682d11ad7',
#    'push_id': 4813324388,
#    'ref': 'refs/heads/master',
#    'size': 3},
#   'public': True,
#   'repo': {'id': 249132410,
#    'name': 'kamitoshi/sample',
#    'url': 'https://api.github.com/repos/kamitoshi/sample'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/47101673?',
#    'display_login': 'pasolini1',
#    'gravatar_id': '',
#    'id': 47101673,
#    'login': 'pasolini1',
#    'url': 'https://api.github.com/users/pasolini1'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805524',
#   'payload': {'before': '60a17726d983fe1c5b0bafbff136916ab66e444f',
#    'commits': [{'author': {'email': 'pasolini@humanoid.net',
#       'name': 'pasolini1'},
#      'distinct': True,
#      'message': "I'll explain when you're older!",
#      'sha': 'ec574568f6404a7b647f45ae2572fa16f5a17050',
#      'url': 'https://api.github.com/repos/pasolini1/FileSonver/commits/ec574568f6404a7b647f45ae2572fa16f5a17050'}],
#    'distinct_size': 1,
#    'head': 'ec574568f6404a7b647f45ae2572fa16f5a17050',
#    'push_id': 4813324395,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 167925846,
#    'name': 'pasolini1/FileSonver',
#    'url': 'https://api.github.com/repos/pasolini1/FileSonver'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/35066786?',
#    'display_login': 'ksbhanegaonkar',
#    'gravatar_id': '',
#    'id': 35066786,
#    'login': 'ksbhanegaonkar',
#    'url': 'https://api.github.com/users/ksbhanegaonkar'},
#   'created_at': '2020-03-25T05:37:34Z',
#   'id': '11855805516',
#   'payload': {'before': '2fe1537d6c6366cb7b12c7140dad8f8c0cca6d2b',
#    'commits': [{'author': {'email': 'kedarsbhanegaonkar@gmail.com',
#       'name': 'ksbhanegaonkar'},
#      'distinct': True,
#      'message': 'Added folder creation logic',
#      'sha': 'f77df95973befda7a5cb4767cfc2ec6dca4c6164',
#      'url': 'https://api.github.com/repos/ksbhanegaonkar/Vaman-OS/commits/f77df95973befda7a5cb4767cfc2ec6dca4c6164'}],
#    'distinct_size': 1,
#    'head': 'f77df95973befda7a5cb4767cfc2ec6dca4c6164',
#    'push_id': 4813324394,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 200873013,
#    'name': 'ksbhanegaonkar/Vaman-OS',
#    'url': 'https://api.github.com/repos/ksbhanegaonkar/Vaman-OS'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/20879548?',
#    'display_login': 'eodccloud',
#    'gravatar_id': '',
#    'id': 20879548,
#    'login': 'eodccloud',
#    'url': 'https://api.github.com/users/eodccloud'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805522',
#   'payload': {'before': '84e2b52b9845b4f870a9684d3dd06c2ef9cef876',
#    'commits': [{'author': {'email': 'eodccloud@mailinator.com',
#       'name': 'eodccloud'},
#      'distinct': True,
#      'message': 'GIT CloneShare Commit',
#      'sha': 'ff2dbdd9ab472a08e2b4c06950dad36b31b6dfce',
#      'url': 'https://api.github.com/repos/eodccloud/Einstein/commits/ff2dbdd9ab472a08e2b4c06950dad36b31b6dfce'}],
#    'distinct_size': 1,
#    'head': 'ff2dbdd9ab472a08e2b4c06950dad36b31b6dfce',
#    'push_id': 4813324389,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 249848349,
#    'name': 'eodccloud/Einstein',
#    'url': 'https://api.github.com/repos/eodccloud/Einstein'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/305718?',
#    'display_login': 'sustrik',
#    'gravatar_id': '',
#    'id': 305718,
#    'login': 'sustrik',
#    'url': 'https://api.github.com/users/sustrik'},
#   'created_at': '2020-03-25T05:37:35Z',
#   'id': '11855805520',
#   'payload': {'before': '9dc6a19690ada746f5bca50d1d2e0b2808fa4083',
#    'commits': [{'author': {'email': 'sustrik@anapaya.net',
#       'name': 'Martin Sustrik'},
#      'distinct': True,
#      'message': 'fix',
#      'sha': '7728ace937ddbbf0039efa9fff27127df0e26616',
#      'url': 'https://api.github.com/repos/sustrik/scion/commits/7728ace937ddbbf0039efa9fff27127df0e26616'}],
#    'distinct_size': 1,
#    'head': '7728ace937ddbbf0039efa9fff27127df0e26616',
#    'push_id': 4813324398,
#    'ref': 'refs/heads/licenses',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 156349337,
#    'name': 'sustrik/scion',
#    'url': 'https://api.github.com/repos/sustrik/scion'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/23428392?',
#    'display_login': 'tacotaco2',
#    'gravatar_id': '',
#    'id': 23428392,
#    'login': 'tacotaco2',
#    'url': 'https://api.github.com/users/tacotaco2'},
#   'created_at': '2020-03-25T05:37:34Z',
#   'id': '11855805517',
#   'payload': {'before': 'a63ac3d08afa46604dd4f990902449c4737c4561',
#    'commits': [{'author': {'email': 'tacotaco2@mailinator.com',
#       'name': 'tacotaco2'},
#      'distinct': True,
#      'message': 'GAS Commit - 03-25-2020 01:37:31',
#      'sha': '1bd367ea9034080cc64547973c53d7378b7b47c0',
# ...
#     'closed_at': None,
#     'comments': 0,
#     'comments_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/issues/47/comments',
#     'created_at': '2020-02-21T05:31:47Z',
#     'events_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/issues/47/events',
#     'html_url': 'https://github.com/ghostslayer989/gitfolio/pull/47',
#     'id': 568745825,
#     'labels': [{'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file',
#       'id': 1369569053,
#       'name': 'dependencies',
#       'node_id': 'MDU6TGFiZWwxMzY5NTY5MDUz',
#       'url': 'https://api.github.com/repos/ghostslayer989/gitfolio/labels/dependencies'}],
#     'labels_url': 'https://api.github.com/repos/ghostslayer989/gitfolio/issues/47/labels{/name}',
#     'locked': False,
#     'milestone': None,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzc4MTExNTE5',
#     'number': 47,
#     'pull_request': {'diff_url': 'https://github.com/ghostslayer989/gitfolio/pull/47.diff',
#      'html_url': 'https://github.com/ghostslayer989/gitfolio/pull/47',
#      'patch_url': 'https://github.com/ghostslayer989/gitfolio/pull/47.patch',
#      'url': 'https://api.github.com/repos/ghostslayer989/gitfolio/pulls/47'},
#     'repository_url': 'https://api.github.com/repos/ghostslayer989/gitfolio',
#     'state': 'open',
#     'title': 'Bump got from 9.6.0 to 10.6.0',
#     'updated_at': '2020-03-25T05:37:34Z',
#     'url': 'https://api.github.com/repos/ghostslayer989/gitfolio/issues/47',
#     'user': {'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'id': 27856297,
#      'login': 'dependabot-preview[bot]',
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'type': 'Bot',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D'}}},
#   'public': True,
#   'repo': {'id': 187677718,
#    'name': 'ghostslayer989/gitfolio',
#    'url': 'https://api.github.com/repos/ghostslayer989/gitfolio'},
#   'type': 'IssueCommentEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/62364243?',
#    'display_login': 'fcc-ea-mirror',
#    'gravatar_id': '',
#    'id': 62364243,
#    'login': 'fcc-ea-mirror',
#    'url': 'https://api.github.com/users/fcc-ea-mirror'},
#   'created_at': '2020-03-25T05:37:34Z',
#   'id': '11855805482',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/62364243?',
#    'gravatar_id': '',
#    'id': 62364243,
#    'login': 'fcc-ea-mirror',
#    'url': 'https://api.github.com/orgs/fcc-ea-mirror'},
#   'payload': {},
#   'public': True,
#   'repo': {'id': 249610586,
#    'name': 'fcc-ea-mirror/UML',
#    'url': 'https://api.github.com/repos/fcc-ea-mirror/UML'},
#   'type': 'PublicEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/4214815?',
#    'display_login': 'MorkaZ',
#    'gravatar_id': '',
#    'id': 4214815,
#    'login': 'MorkaZ',
#    'url': 'https://api.github.com/users/MorkaZ'},
#   'created_at': '2020-03-25T05:37:34Z',
#   'id': '11855805480',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/41555324?',
#    'gravatar_id': '',
#    'id': 41555324,
#    'login': 'BentoBoxWorld',
#    'url': 'https://api.github.com/orgs/BentoBoxWorld'},
#   'payload': {'action': 'created',
#    'comment': {'author_association': 'NONE',
#     'body': 'Thanks a lot tastybento. You have explained it very well. People like me will now have answer in the future.',
#     'created_at': '2020-03-25T05:37:34Z',
#     'html_url': 'https://github.com/BentoBoxWorld/BentoBox/issues/1240#issuecomment-603650643',
#     'id': 603650643,
#     'issue_url': 'https://api.github.com/repos/BentoBoxWorld/BentoBox/issues/1240',
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDYwMzY1MDY0Mw==',
#     'updated_at': '2020-03-25T05:37:34Z',
#     'url': 'https://api.github.com/repos/BentoBoxWorld/BentoBox/issues/comments/603650643',
#     'user': {'avatar_url': 'https://avatars3.githubusercontent.com/u/4214815?v=4',
#      'events_url': 'https://api.github.com/users/MorkaZ/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/MorkaZ/followers',
#      'following_url': 'https://api.github.com/users/MorkaZ/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/MorkaZ/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/MorkaZ',
#      'id': 4214815,
#      'login': 'MorkaZ',
#      'node_id': 'MDQ6VXNlcjQyMTQ4MTU=',
#      'organizations_url': 'https://api.github.com/users/MorkaZ/orgs',
#      'received_events_url': 'https://api.github.com/users/MorkaZ/received_events',
#      'repos_url': 'https://api.github.com/users/MorkaZ/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/MorkaZ/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/MorkaZ/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/MorkaZ'}},
#    'issue': {'assignee': {'avatar_url': 'https://avatars2.githubusercontent.com/u/4407265?v=4',
#      'events_url': 'https://api.github.com/users/tastybento/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/tastybento/followers',
#      'following_url': 'https://api.github.com/users/tastybento/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tastybento/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/tastybento',
#      'id': 4407265,
#      'login': 'tastybento',
#      'node_id': 'MDQ6VXNlcjQ0MDcyNjU=',
#      'organizations_url': 'https://api.github.com/users/tastybento/orgs',
#      'received_events_url': 'https://api.github.com/users/tastybento/received_events',
#      'repos_url': 'https://api.github.com/users/tastybento/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/tastybento/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tastybento/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/tastybento'},
#     'assignees': [{'avatar_url': 'https://avatars2.githubusercontent.com/u/4407265?v=4',
#       'events_url': 'https://api.github.com/users/tastybento/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/tastybento/followers',
#       'following_url': 'https://api.github.com/users/tastybento/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tastybento/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/tastybento',
#       'id': 4407265,
#       'login': 'tastybento',
#       'node_id': 'MDQ6VXNlcjQ0MDcyNjU=',
#       'organizations_url': 'https://api.github.com/users/tastybento/orgs',
#       'received_events_url': 'https://api.github.com/users/tastybento/received_events',
#       'repos_url': 'https://api.github.com/users/tastybento/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/tastybento/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tastybento/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/tastybento'}],
#     'author_association': 'NONE',
#     'body': "### Description\r\n#### Describe the bug\r\n<!-- A clear and concise description of the problem you're encountering. -->\r\n<!-- /!\\ Leaving this section blank will result in your ticket being closed without further explanation. -->\r\n<!-- Please type below this line. -->\r\nI have updated my mysql servers and after that, bentobox spams console with this error:\r\n![image](https://user-images.githubusercontent.com/4214815/77399891-9af77d00-6daa-11ea-98b4-0ec5ca7dca44.png)\r\n\r\n\r\n#### Steps to reproduce the behavior\r\n<!-- Step-by-step instructions for us to reproduce the bug on our side. -->\r\n<!-- /!\\ Leaving this section blank will result in your ticket being closed without further explanation. -->\r\n<!-- Please type below this line. -->\r\nUse latested MariaDB or MySQL server. Tested on both - same result. Only Bentobox has problems, any other plugin works fine.\r\n\r\n#### Expected behavior\r\n<!-- What do you think should happen? -->\r\n<!-- Please type below this line. -->\r\n\r\n#### Screenshots and videos (Optional)\r\n<!-- Videos and screenshots are helpful as they can provide better information about your problem. -->\r\n<!-- Please type below this line. -->\r\n\r\n### Environment\r\n\r\n##### BentoBox Version (Mandatory)\r\n<!-- /!\\ Leaving this section blank will result in your ticket being closed without further explanation. -->\r\n<!-- Paste the output of `/bentobox version` in the code block below (replace the underscores). Do not provide an image. -->\r\n```\r\n1.11.0\r\n```\r\n\r\n#### Plugins (Optional)\r\n<!-- Please paste the `/plugins` output inside the code block below (remove the underscores). Do not provide an image. -->\r\n```\r\n[08:38:31 INFO]: Plugins (48): ActionHealth*, antiRedstoneClock, AuctionHouse, BentoBox, BossShopPro, ChatInjector*, ClearLag, ColoredSigns*, CommandButtons, CraftBook, Essentials, EssentialsChat, EssentialsProtect, EssentialsSpawn, HeadDatabase*, HolographicDisplays, ItemShops*, LiteJoin*, MorkazSk, MoxChatTitles, MoxCore, MoxFables, MoxPerms*, MoxPlayerParticles, MoxPremiumShop, MoxTokensDatabase*, MoxTransmutators, Multiverse-Core*, NoCheatPlus, PlaceholderAPI, PlugMan, ProtocolLib, ProtocolSupport, SAML, SK-NBeeT, SkQuery, skRayFall*, Skript, spark, SQLibrary*, TAB, TuSKe*, Vault, VoidGenerator, WorldBorder, WorldBorderAPI*, WorldEdit, WorldGuard\r\n```\r\n \r\n### Additional context (Optional)\r\n<!-- Any additional information you'd like to provide us. -->\r\n<!-- Please type below this line. -->\r\n",
#     'closed_at': None,
#     'comments': 7,
#     'comments_url': 'https://api.github.com/repos/BentoBoxWorld/BentoBox/issues/1240/comments',
#     'created_at': '2020-03-24T07:38:45Z',
#     'events_url': 'https://api.github.com/repos/BentoBoxWorld/BentoBox/issues/1240/events',
#     'html_url': 'https://github.com/BentoBoxWorld/BentoBox/issues/1240',
#     'id': 586756403,
#     'labels': [{'color': 'fbca04',
#       'default': False,
#       'description': 'Investigating the interest and the feasability of the issue.',
#       'id': 647820275,
#       'name': 'Status: Under investigation',
#       'node_id': 'MDU6TGFiZWw2NDc4MjAyNzU=',
#       'url': 'https://api.github.com/repos/BentoBoxWorld/BentoBox/labels/Status:%20Under%20investigation'}],
#     'labels_url': 'https://api.github.com/repos/BentoBoxWorld/BentoBox/issues/1240/labels{/name}',
#     'locked': False,
#     'milestone': None,
#     'node_id': 'MDU6SXNzdWU1ODY3NTY0MDM=',
#     'number': 1240,
#     'repository_url': 'https://api.github.com/repos/BentoBoxWorld/BentoBox',
#     'state': 'open',
#     'title': 'Error spam "[BentoBox] Could not check if key exists in database!" after MariaDB/MySQL version update',
#     'updated_at': '2020-03-25T05:37:34Z',
#     'url': 'https://api.github.com/repos/BentoBoxWorld/BentoBox/issues/1240',
#     'user': {'avatar_url': 'https://avatars3.githubusercontent.com/u/4214815?v=4',
#      'events_url': 'https://api.github.com/users/MorkaZ/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/MorkaZ/followers',
#      'following_url': 'https://api.github.com/users/MorkaZ/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/MorkaZ/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/MorkaZ',
#      'id': 4214815,
#      'login': 'MorkaZ',
#      'node_id': 'MDQ6VXNlcjQyMTQ4MTU=',
#      'organizations_url': 'https://api.github.com/users/MorkaZ/orgs',
#      'received_events_url': 'https://api.github.com/users/MorkaZ/received_events',
#      'repos_url': 'https://api.github.com/users/MorkaZ/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/MorkaZ/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/MorkaZ/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/MorkaZ'}}},
#   'public': True,
#   'repo': {'id': 91916253,
#    'name': 'BentoBoxWorld/BentoBox',
#    'url': 'https://api.github.com/repos/BentoBoxWorld/BentoBox'},
#   'type': 'IssueCommentEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/1480995?',
#    'display_login': 'bigpopakap',
#    'gravatar_id': '',
#    'id': 1480995,
#    'login': 'bigpopakap',
#    'url': 'https://api.github.com/users/bigpopakap'},
#   'created_at': '2020-03-25T05:37:34Z',
#   'id': '11855805473',
#   'payload': {'before': 'fb9fc676fbc7aa578a2489f801fb920d4d91c9a7',
#    'commits': [{'author': {'email': 'semantic-release-bot@martynus.net',
#       'name': 'semantic-release-bot'},
#      'distinct': True,
#      'message': 'chore(@projitect/fp-ts-utils): release 1.0.0-alpha.2 [skip ci]\n\n# [@projitect/fp-ts-utils-v1.0.0-alpha.2](https://github.com/bigpopakap/projitect/compare/v1.0.0-alpha.1-@projitect/fp-ts-utils...v1.0.0-alpha.2-@projitect/fp-ts-utils) (2020-03-25)\n\n### Features\n\n* add getFirstRightOrLefts util function ([ce5735d](https://github.com/bigpopakap/projitect/commit/ce5735db61b88336e7a96e39c52f855d6d40d2c9))',
#      'sha': 'd9c596f2c187b726a840bb93c1c454f582fb94f8',
#      'url': 'https://api.github.com/repos/bigpopakap/projitect/commits/d9c596f2c187b726a840bb93c1c454f582fb94f8'}],
#    'distinct_size': 1,
#    'head': 'd9c596f2c187b726a840bb93c1c454f582fb94f8',
#    'push_id': 4813324371,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 220725663,
#    'name': 'bigpopakap/projitect',
#    'url': 'https://api.github.com/repos/bigpopakap/projitect'},
#   'type': 'PushEvent'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json

f = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(f.text)
# Out:
# {'all': [{'_id': '58e008ad0aac31001185ed0c',
#    'text': "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#    'type': 'cat',
#    'upvotes': 11,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'upvotes': 7,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'upvotes': 6,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'upvotes': 6,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
#    'text': 'Cat owners are 17% more likely to have a graduate degree than non cat owners.',
#    'type': 'cat',
#    'upvotes': 6,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'upvotes': 6,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'upvotes': 5,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'upvotes': 5,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'upvotes': 4,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'upvotes': 4,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'upvotes': 4,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'upvotes': 4,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'upvotes': 4,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'upvotes': 4,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'upvotes': 4,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'upvotes': 4,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '58e00a090aac31001185ed16',
#    'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#    'type': 'cat',
#    'upvotes': 4,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'upvotes': 4,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'upvotes': 4,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'upvotes': 4,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'upvotes': 3,
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'upvotes': 3,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'upvotes': 3,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'upvotes': 2,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c489117e4f6130014c987b9',
#    'text': 'Leonardo da Vinci created a series of drawings titled "Study of Cat Movements and Positions", which consists of more than twenty drawings of cats and lions lying a sleep, sitting, playing, and fighting.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c60982ce549020014533033',
#    'text': 'The Chartreux is distinguished by a woolly blue-grey coat, a robust body poised over small paws, and full cheeks with a mouth that always appear to be smiling.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c609852e549020014533036',
#    'text': "While Chartreux cats aren't very vocal, they are sociable and communicate through eye contact and body language.",
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c60999ae549020014533038',
#    'text': 'Cats love playing with yarn, ribbons, and fishing-rode style toys. However, cats should not be left alone with anything that they could get tangled in.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c609a02e549020014533039',
#    'text': "All Scottish Folds descended from Susie, a white barn cat discovered in Scotland in the early 1960s. Susie sported the breed's folded ears – the result of a genetic mutation – and passed on the trait through breeding.",
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c609a90e54902001453303a',
#    'text': 'Mark Twain was undeniably an ailurophile. He had up to 19 cats at one time and gave them such memorable names as Beelzebub, Buffalo Bill, and Soapy Sal.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c69c35cc2d7a200140f67ea',
#    'text': 'If you really want to treat your cat, get some lactose-free milk at the grocery store and offer some to the kitty.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c69c47dc2d7a200140f67ee',
#    'text': 'Abraham Lincoln, being the ailurophile that he was, once rescued three stray kittens and ensured that they were fed and found homes.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c69c4eec2d7a200140f67ef',
#    'text': 'The Sphynx was originally known as the Canadian Hairless Cat. The breed originated in Toronto, and was renamed to Sphynx, a nod to the famous limestone sculpture in the Egyptian Desert.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c6a104fc2d7a200140f699f',
#    'text': 'A cat’s spine can rotate more than the spines of most other animals, and their vertebrae have a special, flexible, elastic cushioning on the disks, which gives it even more flexibility.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c72d9b651021f001415f00c',
#    'text': 'Cats have been domesticated for around 4,000 years. While they were once valued for their hunting abilities, they are now valued for their companionship and loving behavior.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5c6fd96df4256a001498a73f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'userUpvoted': None},
#   {'_id': '5c72dbd851021f001415f010',
#    'text': 'The most popular pedigreed cat in North America is the Persian cat, followed by the Main Coon and the Siamese cat.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5c72dbb751021f001415f00f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'userUpvoted': None},
#   {'_id': '5de780600013130015a3ccaf',
#    'text': 'About one in two cats respond to catnip, and only develop a sensitivity to it at around 3 to 6 months of age.',
#    'type': 'cat',
# ...
#    'userUpvoted': None},
#   {'_id': '5c609945e549020014533037',
#    'text': 'Do you ever wake up in the middle of the night and find your cat sleeping on your head? Cat behavioral experts believe that cats are drawn to the warmth and the familiar scent of the owner. Resting on your head also keeps kitty safe from your arms and legs if you toss and turn through the night.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c7408a14dd87d001490f02b',
#    'text': "The cheetah is the only cat that doesn't have retractable claws.",
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5c72e94751021f001415f012',
#     'name': {'first': 'Tests', 'last': 'HiQ'}},
#    'userUpvoted': None},
#   {'_id': '5c75f56272681400147b988a',
#    'text': 'There are only two escalators in the state of Wyoming.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c84248f731a60001540a193',
#    'text': 'When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, "elevator butt" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5c7da4bd70008708fb17c88f',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5c87d03dec1e5c0aa37e0a6b',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'type': 'cat',
#    'upvotes': 1,
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'text': 'Some cats do not eat fish.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'userUpvoted': None},
#   {'_id': '5e239999dc76630015d4c5e2',
#    'text': 'Cats see only on blue and yellow.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e239963dc76630015d4c5e1',
#     'name': {'first': 'Eduardo', 'last': 'P. Gomez'}},
#    'userUpvoted': None},
#   {'_id': '5e27232ec71d0900152d8518',
#    'text': 'Cats are dumb.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e272323c71d0900152d8517',
#     'name': {'first': 'Andrew', 'last': 'Steele'}},
#    'userUpvoted': None},
#   {'_id': '5e2f9f1ade397c00152dd552',
#    'text': 'Cat.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'userUpvoted': None},
#   {'_id': '5e2f9f23de397c00152dd553',
#    'text': 'Sleep.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'userUpvoted': None},
#   {'_id': '5e3382ccd7ac48001509e153',
#    'text': 'Cat is an animal.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e3381f3d7ac48001509e151',
#     'name': {'first': 'Dicka', 'last': 'Ismaji'}},
#    'userUpvoted': None},
#   {'_id': '5e344e7acd8efb0015ae3055',
#    'text': 'Cat live, on average, for about 7-8 years.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e344e3ccd8efb0015ae3054',
#     'name': {'first': 'RYAN', 'last': 'STULTZ'}},
#    'userUpvoted': None},
#   {'_id': '5e3534d8cd8efb0015ae305c',
#    'text': 'Hi.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'userUpvoted': None},
#   {'_id': '5e35436d11559000151bf453',
#    'text': '123.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'userUpvoted': None},
#   {'_id': '5e355bf411559000151bf454',
#    'text': 'Fgf.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'userUpvoted': None},
#   {'_id': '5e380ea32035630015618254',
#    'text': 'Asd.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e380e9b2035630015618253',
#     'name': {'first': 'dm', 'last': 'max'}},
#    'userUpvoted': None},
#   {'_id': '5e56fdf375991a0015429ffc',
#    'text': 'Bbb.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e56fddd75991a0015429ffb',
#     'name': {'first': 'Cristian', 'last': 'Salcedo'}},
#    'userUpvoted': None},
#   {'_id': '5e5fa8834bbe5000159a40c8',
#    'text': 'Helo.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e5fa8764bbe5000159a40c7',
#     'name': {'first': 'Umesh', 'last': 'Golla'}},
#    'userUpvoted': None},
#   {'_id': '5e6101691ef5490015babb5e',
#    'text': '4564.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e6101581ef5490015babb5d',
#     'name': {'first': 'Анна', 'last': 'Абрамова'}},
#    'userUpvoted': None},
#   {'_id': '5e6101741ef5490015babb5f',
#    'text': '46546.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e6101581ef5490015babb5d',
#     'name': {'first': 'Анна', 'last': 'Абрамова'}},
#    'userUpvoted': None},
#   {'_id': '5e63c838d681170015d920c6',
#    'text': 'Persa.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e63c82dd681170015d920c5',
#     'name': {'first': 'Ivo', 'last': 'Baptista'}},
#    'userUpvoted': None},
#   {'_id': '5e64033ad681170015d920c9',
#    'text': 'Speed.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e640328d681170015d920c8',
#     'name': {'first': 'Peter', 'last': 'Seboyeng'}},
#    'userUpvoted': None},
#   {'_id': '5e66d61767112d00157b0d80',
#    'text': 'Aptude Luis.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e66d5ec67112d00157b0d7d',
#     'name': {'first': 'luisnoe', 'last': 'jasso'}},
#    'userUpvoted': None},
#   {'_id': '5e747f3e265890001533fcec',
#    'text': '貓貓.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e747f19265890001533fceb',
#     'name': {'first': '橿', 'last': '孟'}},
#    'userUpvoted': None},
#   {'_id': '5e79b5adcca7670015e74b4d',
#    'text': 'Hello World.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e79b588cca7670015e74b4c',
#     'name': {'first': 'Sanjay', 'last': 'Sarkar'}},
#    'userUpvoted': None},
#   {'_id': '5e7a4017cca7670015e74b4f',
#    'text': 'Cats is good.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e7a3ffecca7670015e74b4e',
#     'name': {'first': 'Геннадий', 'last': 'Сычик'}},
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'userUpvoted': None},
#   {'_id': '5e4c4e10a38ae60015b04a7e',
#    'text': "Cats think humans have night vision too, so when we step on their tail in the middle of the night, they think it's on purpose.",
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e4c4dc5a38ae60015b04a7d',
#     'name': {'first': 'Nathaniel J', 'last': 'McDermott'}},
#    'userUpvoted': None},
#   {'_id': '5e546a054e83e80015a0e320',
#    'text': "Contrary to popular belief, some cats actually don't mind water. The hairless Sphynx cat enjoys it, especially if it is warm.",
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e54675a4e83e80015a0e313',
#     'name': {'first': "L'hibou", 'last': 'Ambigu'}},
#    'userUpvoted': None},
#   {'_id': '5e66bb2967112d00157b0d7c',
#    'text': 'Cca.',
#    'type': 'cat',
#    'upvotes': 0,
#    'user': {'_id': '5e66bb1367112d00157b0d7b',
#     'name': {'first': 'Ivan', 'last': 'Mercedes'}},
#    'userUpvoted': None}]}
